# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# A) Generate a random array of 50 integers and display them using a line chart, scatter
# plot, histogram and box plot. Apply appropriate color, labels and styling options.

# %%
data = np.random.randint(1, 101, 50)
data
# Out:
# array([81, 79, 79, 41, 34, 78, 13, 88, 14, 84, 89, 98,  6, 84,  9,  8, 87,
#        85, 64,  1, 40,  2, 93, 42, 30, 61, 94, 46, 16,  9, 56, 17, 10, 57,
#        96, 14,  5, 63, 76, 99, 46, 74, 15, 96, 35, 58, 46, 11, 56, 94])

# %%
plt.subplot(2,2,1)
plt.plot(data, color = 'r')
plt.title("Line Plot")

plt.subplot(2,2,2)
plt.scatter(range(50), data, marker = "*")
plt.title("Scatter Plot")

plt.subplot(2,2,3)
plt.hist(data, color = "yellow")
plt.title("HIstogram Plot")

plt.subplot(2,2,4)
sns.boxplot(data = data, color = 'g')
plt.title("Box Plot")

plt.tight_layout()
plt.show()

# %% [markdown]
# B) Write a Python program to print the shape, number of rows-columns, data types,
# feature names and the description of the data(Use User_Data.csv)

# %%
dataset = pd.read_csv("user_data.csv")
dataset
# Out:
#      Unnamed: 0.1  Unnamed: 0  user_id  room_id  hygeine_rating  staff_rating  \
# 0               0           0        0        0               1             4
# 1               1           1        1        1               4             0
# 2               2           2        2        2               0             2
# 3               3           3        3        3               3             1
# 4               4           4        4        4               5             2
# ..            ...         ...      ...      ...             ...           ...
# 326           326         326      326      326               4             1
# 327           327         327      327      327               2             5
# 328           328         328      328      328               0             4
# 329           329         329      329      329               3             3
# 330           330         330      330      330               4             5
#
#      comfort_rating  average_rating
# 0                 4        3.000000
# 1                 2        2.000000
# 2                 0        0.666667
# 3                 3        2.333333
# 4                 4        3.666667
# ..              ...             ...
# 326               0        1.666667
# 327               3        3.333333
# 328               5        3.000000
# 329               4        3.333333
# 330               5        4.666667
#
# [331 rows x 8 columns]

# %%
dataset.shape
# Out:
# (331, 8)

# %%
print("Rows : ",dataset.shape[0])
# Out:
# Rows :  331

# %%
print("Columns : ",dataset.shape[1])
# Out:
# Columns :  8

# %%
print("Features : ",dataset.dtypes)
# Out:
# Features :  Unnamed: 0.1        int64
# Unnamed: 0          int64
# user_id             int64
# room_id             int64
# hygeine_rating      int64
# staff_rating        int64
# comfort_rating      int64
# average_rating    float64
# dtype: object

# %%
print("Feature Name : ",dataset.columns.tolist())
# Out:
# Feature Name :  ['Unnamed: 0.1', 'Unnamed: 0', 'user_id', 'room_id', 'hygeine_rating', 'staff_rating', 'comfort_rating', 'average_rating']

# %%
dataset.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0     user_id     room_id  hygeine_rating  \
# count    331.000000  331.000000  331.000000  331.000000      331.000000
# mean     165.000000  165.000000  165.000000  165.000000        2.716012
# std       95.695698   95.695698   95.695698   95.695698        1.681725
# min        0.000000    0.000000    0.000000    0.000000        0.000000
# 25%       82.500000   82.500000   82.500000   82.500000        1.000000
# 50%      165.000000  165.000000  165.000000  165.000000        3.000000
# 75%      247.500000  247.500000  247.500000  247.500000        4.000000
# max      330.000000  330.000000  330.000000  330.000000        5.000000
#
#        staff_rating  comfort_rating  average_rating
# count    331.000000      331.000000      331.000000
# mean       2.507553        2.528701        2.584089
# std        1.782687        1.714888        0.951286
# min        0.000000        0.000000        0.333333
# 25%        1.000000        1.000000        2.000000
# 50%        3.000000        3.000000        2.666667
# 75%        4.000000        4.000000        3.333333
# max        5.000000        5.000000        5.000000
