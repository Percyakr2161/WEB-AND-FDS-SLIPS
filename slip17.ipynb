# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# A) Write a Python program to draw scatter plots to compare two features of the iris dataset

# %%
dataset = pd.read_csv('iris.csv')
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(data = dataset, x = 'sepal_length', y = 'petal_length',hue = 'species', marker = "*")
plt.show()

# %% [markdown]
# B)Create two lists, one representing subject names and the other representing marks
# obtained in those subjects. Display the data in a pie chart and bar chart.

# %%
subject = ["Maths", "Science", "FDS", "Python", "CN2", "Java"]
marks = [23, 34, 56, 67, 78, 65]

plt.subplot(2,2,1)
plt.pie(marks, labels = subject, autopct = '%1.1f%%')
plt.title("Pie Chart")

plt.subplot(2,2,2)
plt.bar(subject, marks, color = 'k')

plt.tight_layout()
plt.show()
