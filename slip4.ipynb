# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Generate a random array of 50 integers and display them using a line chart, scatterplot,
# histogram and box plot. Apply appropriate color, labels and styling options.

# %%
data = np.random.randint(1, 101, 50)
data
# Out:
# array([67,  7, 79, 33, 75, 44, 99,  1, 34, 85, 16, 64, 11, 75, 96, 57, 27,
#         8, 29, 87, 47, 11, 13, 79, 18, 16, 26, 79, 64, 86, 46, 44, 13, 46,
#        60, 92, 73, 12, 10, 95, 56,  9, 79, 26,  2, 23, 15, 15, 70, 70])

# %%
plt.subplot(2,2,1)
plt.plot(data, color = 'r')
plt.title("Line Plot")

plt.subplot(2,2,2)
plt.scatter(range(50), data, marker = "*")
plt.title("Scatter Plot")

plt.subplot(2,2,3)
plt.hist(data, color = "yellow")
plt.title("HIstogram Plot")

plt.subplot(2,2,4)
sns.boxplot(data = data, color = 'g')
plt.title("Box Plot")

plt.tight_layout()
plt.show()

# %% [markdown]
# 2 B) Write a Python program to print the shape, number of rows-columns, data types,
# feature names and the description of the data. (Use User_Data.csv)

# %%
dataset = pd.read_csv("user_data.csv")
dataset
# Out:
#      Unnamed: 0.1  Unnamed: 0  user_id  room_id  hygeine_rating  staff_rating  \
# 0               0           0        0        0               1             4
# 1               1           1        1        1               4             0
# 2               2           2        2        2               0             2
# 3               3           3        3        3               3             1
# 4               4           4        4        4               5             2
# ..            ...         ...      ...      ...             ...           ...
# 326           326         326      326      326               4             1
# 327           327         327      327      327               2             5
# 328           328         328      328      328               0             4
# 329           329         329      329      329               3             3
# 330           330         330      330      330               4             5
#
# ...

# %%
dataset.shape
# Out:
# (331, 8)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331 entries, 0 to 330
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0.1    331 non-null    int64
#  1   Unnamed: 0      331 non-null    int64
#  2   user_id         331 non-null    int64
#  3   room_id         331 non-null    int64
#  4   hygeine_rating  331 non-null    int64
#  5   staff_rating    331 non-null    int64
#  6   comfort_rating  331 non-null    int64
#  7   average_rating  331 non-null    float64
# dtypes: float64(1), int64(7)
# memory usage: 20.8 KB

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'user_id', 'room_id', 'hygeine_rating',
#        'staff_rating', 'comfort_rating', 'average_rating'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0     user_id     room_id  hygeine_rating  \
# count    331.000000  331.000000  331.000000  331.000000      331.000000
# mean     165.000000  165.000000  165.000000  165.000000        2.716012
# std       95.695698   95.695698   95.695698   95.695698        1.681725
# min        0.000000    0.000000    0.000000    0.000000        0.000000
# 25%       82.500000   82.500000   82.500000   82.500000        1.000000
# 50%      165.000000  165.000000  165.000000  165.000000        3.000000
# 75%      247.500000  247.500000  247.500000  247.500000        4.000000
# max      330.000000  330.000000  330.000000  330.000000        5.000000
#
#        staff_rating  comfort_rating  average_rating
# count    331.000000      331.000000      331.000000
# mean       2.507553        2.528701        2.584089
# std        1.782687        1.714888        0.951286
# min        0.000000        0.000000        0.333333
# 25%        1.000000        1.000000        2.000000
# ...
